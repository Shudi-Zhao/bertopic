# %% [markdown]
# # BERTopic Learning Vidualizations
#
# https://maartengr.github.io/BERTopic/getting_started/visualization/visualize_topics.html#visualize-topic-similarity

# %% [markdown]
# ## Topics

# %% [markdown]
# ### Vidualize Topics

# %%
import pandas as pd
import numpy as np

from bertopic import BERTopic
from sklearn.datasets import fetch_20newsgroups

docs = fetch_20newsgroups(subset='all',  remove=('headers', 'footers', 'quotes'))['data']
topic_model = BERTopic()
topics, probs = topic_model.fit_transform(docs)
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# ...

# %%
len(docs)
# Out:
# 18846

# %%
topic_model.visualize_topics()

# %% [markdown]
# ### Visualize Topic Similarity

# %%
topic_model.visualize_heatmap(n_clusters=5)

# %% [markdown]
# ### Visualize Topics over Time

# %%
import re
import pandas as pd
from bertopic import BERTopic

# Prepare data
trump = pd.read_csv('https://drive.google.com/uc?export=download&id=1xRKHaP-QwACMydlDnyFPEaFdtskJuBa6')
trump.text = trump.apply(lambda row: re.sub(r"http\S+", "", row.text).lower(), 1)
trump.text = trump.apply(lambda row: " ".join(filter(lambda x:x[0]!="@", row.text.split())), 1)
trump.text = trump.apply(lambda row: " ".join(re.sub("[^a-zA-Z]+", " ", row.text).split()), 1)
trump = trump.loc[(trump.isRetweet == "f") & (trump.text != ""), :]
timestamps = trump.date.to_list()
tweets = trump.text.to_list()

# Create topics over time
model = BERTopic(verbose=True)
topics, probs = model.fit_transform(tweets)
topics_over_time = model.topics_over_time(tweets, timestamps)
# Out:
# 2025-03-06 10:08:42,762 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/1418 [00:00<?, ?it/s]
# 2025-03-06 10:09:10,682 - BERTopic - Embedding - Completed ✓
# 2025-03-06 10:09:10,682 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-03-06 10:09:20,468 - BERTopic - Dimensionality - Completed ✓
# 2025-03-06 10:09:20,470 - BERTopic - Cluster - Start clustering the reduced embeddings
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# ...

# %%
trump
# Out:
#                         id                                               text  \
# 0        98454970654916608  republicans and democrats have both created ou...
# 1      1234653427789070336  i was thrilled to be back in the great city of...
# 3      1304875170860015617  the unsolicited mail in ballot scam is a major...
# 6      1223640662689689602             getting a little exercise this morning
# 14     1215247978966986752                                    thank you elise
# ...                    ...                                                ...
# 56555  1213078681750573056  iran never won a war but never lost a negotiation
# 56559  1212177432452698115  thank you to the washington examiner the list ...
# 56560  1212175360093229056  one of my greatest honors was to have gotten c...
# 56569  1319384118849949702  just signed an order to support the workers of...
# 56570  1319345719829008387  suburban women want safety amp security joe bi...
#
# ...

# %%
topic_model.visualize_topics()

# %%
model.visualize_topics_over_time(topics_over_time, topics=[0, 1, 2])

# %% [markdown]
# ## Visualize Topics per Class

# %%
from bertopic import BERTopic
from sklearn.datasets import fetch_20newsgroups

# Prepare data and classes
data = fetch_20newsgroups(subset='all',  remove=('headers', 'footers', 'quotes'))
docs = data["data"]
classes = [data["target_names"][i] for i in data["target"]]

# Create topic model and calculate topics per class
topic_model = BERTopic()
topics, probs = topic_model.fit_transform(docs)
topics_per_class = topic_model.topics_per_class(docs, classes=classes)
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# ...

# %%
topic_model.visualize_topics_per_class(topics_per_class)
